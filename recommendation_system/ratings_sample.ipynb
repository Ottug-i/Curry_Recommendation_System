# %% [markdown]
# # 장르가 나누어진 데이터를 가지고 평점 매기기

# %% [markdown]
# ## 레시피 데이터 받아오기

# %%
import pandas as pd

# %%
# 샘플로 작성
# recipes = pd.read_csv('/content/drive/MyDrive/curry_data/curry_recipe_genre_sample.csv', index_col='id')
recipes = pd.read_csv('/content/drive/MyDrive/curry_data/curry_recipe_genre_sample.csv')
recipes
# Out:
#         id                          genre      name composition  \
# 0  6842324                          ing13     고구마맛탕         가볍게
# 1  6845721          ing5|ing10|ing9|ing14  참치샐러드비빔밥        든든하게
# 2  6845906  ing13|ing15|ing25|ing11|ing14  해쉬브라운그라탕        든든하게
# 3  6846020   ing2|ing25|ing10|ing11|ing15     식빵핫도그         가볍게
# 4  6846262                    ing22|ing25    딸기컵케이크         가볍게
#
#                                          ingredients servings difficulty  \
# 0                   [재료] 고구마| 식용유| 황설탕| 올리고당| 견과류| 물      2인분         초급
# 1  [재료] 참치 통조림 1캔| 쌈채소 1줌| 밥 1공기| 초고추장 적당히 [선택재료]...      1인분        아무나
# 2  [필수재료] 해쉬브라운(냉동감자) 4장| 올리브유 적당량| 토마토소스 2/3컵| 슈...      2인분         초급
# 3  [필수재료] 식빵 3장| 소시지 3개| 슬라이스치즈 3장| 달걀 2개| 빵가루 1컵...      1인분         초급
# 4  [필수재료] 머핀 2개| 딸기 8개| 플레인요구르트 1컵 [선택재료] 판 초콜릿 적...      2인분        아무나
#
#                                            thumbnail    time  \
# 0  https://recipe1.ezmember.co.kr/cache/recipe/20...  60분 이내
# 1  https://recipe1.ezmember.co.kr/cache/recipe/20...  10분 이내
# 2  https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
# 3  https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
# 4  https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
#
#                                               orders  \
# 0       |1. 바삭하게 튀기는 꿀팁|2. 달콤한 소스 꿀팁|3. 더 건강하게 먹는 꿀팁
# 1  |1. 참치는 캔 뚜껑을 따서 기름기를 따라낸다.|2. 볼에 참치를 넣고 다진 양파...
# 2  |1. 뜨겁게 달군 팬에 올리브유(2큰술)를 두르고 채 썬 양파와 다진 마늘(½큰술...
# 3  |1. 식빵은 밀대를 이용해 납작하게 민다.|2. 깻잎 ? 슬라이스치즈 - 소시지 ...
# 4  |1. 머핀은 사방 1.5cm 크기로 썰어요.|2. 판초콜릿은 칼로 잘게 부숴요.|...
#
#                                                photo
# 0  |https://recipe1.ezmember.co.kr/cache/recipe/2...
# 1  |https://recipe1.ezmember.co.kr/cache/recipe/2...
# 2  |https://recipe1.ezmember.co.kr/cache/recipe/2...
# 3  |https://recipe1.ezmember.co.kr/cache/recipe/2...
# 4  |https://recipe1.ezmember.co.kr/cache/recipe/2...

# %%
recipes['genre']
# Out:
# 0                            ing13
# 1            ing5|ing10|ing9|ing14
# 2    ing13|ing15|ing25|ing11|ing14
# 3     ing2|ing25|ing10|ing11|ing15
# 4                      ing22|ing25
# Name: genre, dtype: object

# %% [markdown]
# ## 페르소나 (가상 유저) 데이터 프레임 생성

# %%
# 샘플로 작성 - 페르소나 2, 3, 27, 34번 유저
personae = [[1, 'ing21|ing5|ing16', 'ing25'], [2, 'ing17|ing22|ing25', 'ing11'], [3, 'ing10|ing18|ing2', 'ing25'], [4, 'ing1', 'ing23|ing12|ing14']]
personae = pd.DataFrame(personae, columns=['userId', 'Good', 'Bad'])
# personae.set_index('userId', inplace=True)

# %%
personae
# Out:
#    userId               Good                Bad
# 0       1   ing21|ing5|ing16              ing25
# 1       2  ing17|ing22|ing25              ing11
# 2       3   ing10|ing18|ing2              ing25
# 3       4               ing1  ing23|ing12|ing14

# %% [markdown]
# ## 페르소나의 선호 장르 데이터를 이용하여 레시피 평점 계산하기

# %%
import re

# %%
ratings = []

for index, user in personae.iterrows():
  for idx, recipe in recipes.iterrows():
    recipe_genre_list = recipe['genre'].split('|')
    personae_good = user['Good'].split('|')
    personae_bad = user['Bad'].split('|')
    rating = 5
    for j in recipe_genre_list:
      for p in personae_good:
        if (j == p):
          rating += 1
      for q in personae_bad:
        if (j == q):
          rating -= 1
  # print(user['userId'])
  # print(recipes.loc[index, 'id'])
    print(recipe['id'])
    ratings.append([recipe['id'], user['userId'], rating])
ratings = pd.DataFrame(ratings, columns=['id', 'userId', 'rating'])
# Out:
# 6842324
# 6845721
# 6845906
# 6846020
# 6846262
# 6842324
# 6845721
# 6845906
# 6846020
# 6846262
# 6842324
# 6845721
# 6845906
# 6846020
# 6846262
# 6842324
# 6845721
# 6845906
# 6846020
# 6846262

# %%
ratings
# Out:
#          id  userId  rating
# 0   6842324       1       5
# 1   6845721       1       6
# 2   6845906       1       4
# 3   6846020       1       4
# 4   6846262       1       4
# 5   6842324       2       5
# 6   6845721       2       5
# 7   6845906       2       5
# 8   6846020       2       5
# 9   6846262       2       7
# 10  6842324       3       5
# 11  6845721       3       6
# 12  6845906       3       4
# 13  6846020       3       6
# 14  6846262       3       4
# 15  6842324       4       5
# 16  6845721       4       4
# 17  6845906       4       4
# 18  6846020       4       5
# 19  6846262       4       5

# %%
recipe_ratings = pd.merge(recipes, ratings, how='outer', on='id')
recipe_ratings
# Out:
#          id                          genre      name composition  \
# 0   6842324                          ing13     고구마맛탕         가볍게
# 1   6842324                          ing13     고구마맛탕         가볍게
# 2   6842324                          ing13     고구마맛탕         가볍게
# 3   6842324                          ing13     고구마맛탕         가볍게
# 4   6845721          ing5|ing10|ing9|ing14  참치샐러드비빔밥        든든하게
# 5   6845721          ing5|ing10|ing9|ing14  참치샐러드비빔밥        든든하게
# 6   6845721          ing5|ing10|ing9|ing14  참치샐러드비빔밥        든든하게
# 7   6845721          ing5|ing10|ing9|ing14  참치샐러드비빔밥        든든하게
# 8   6845906  ing13|ing15|ing25|ing11|ing14  해쉬브라운그라탕        든든하게
# 9   6845906  ing13|ing15|ing25|ing11|ing14  해쉬브라운그라탕        든든하게
# 10  6845906  ing13|ing15|ing25|ing11|ing14  해쉬브라운그라탕        든든하게
# 11  6845906  ing13|ing15|ing25|ing11|ing14  해쉬브라운그라탕        든든하게
# 12  6846020   ing2|ing25|ing10|ing11|ing15     식빵핫도그         가볍게
# 13  6846020   ing2|ing25|ing10|ing11|ing15     식빵핫도그         가볍게
# 14  6846020   ing2|ing25|ing10|ing11|ing15     식빵핫도그         가볍게
# 15  6846020   ing2|ing25|ing10|ing11|ing15     식빵핫도그         가볍게
# 16  6846262                    ing22|ing25    딸기컵케이크         가볍게
# 17  6846262                    ing22|ing25    딸기컵케이크         가볍게
# 18  6846262                    ing22|ing25    딸기컵케이크         가볍게
# 19  6846262                    ing22|ing25    딸기컵케이크         가볍게
#
#                                           ingredients servings difficulty  \
# 0                    [재료] 고구마| 식용유| 황설탕| 올리고당| 견과류| 물      2인분         초급
# 1                    [재료] 고구마| 식용유| 황설탕| 올리고당| 견과류| 물      2인분         초급
# 2                    [재료] 고구마| 식용유| 황설탕| 올리고당| 견과류| 물      2인분         초급
# 3                    [재료] 고구마| 식용유| 황설탕| 올리고당| 견과류| 물      2인분         초급
# 4   [재료] 참치 통조림 1캔| 쌈채소 1줌| 밥 1공기| 초고추장 적당히 [선택재료]...      1인분        아무나
# 5   [재료] 참치 통조림 1캔| 쌈채소 1줌| 밥 1공기| 초고추장 적당히 [선택재료]...      1인분        아무나
# 6   [재료] 참치 통조림 1캔| 쌈채소 1줌| 밥 1공기| 초고추장 적당히 [선택재료]...      1인분        아무나
# 7   [재료] 참치 통조림 1캔| 쌈채소 1줌| 밥 1공기| 초고추장 적당히 [선택재료]...      1인분        아무나
# 8   [필수재료] 해쉬브라운(냉동감자) 4장| 올리브유 적당량| 토마토소스 2/3컵| 슈...      2인분         초급
# 9   [필수재료] 해쉬브라운(냉동감자) 4장| 올리브유 적당량| 토마토소스 2/3컵| 슈...      2인분         초급
# 10  [필수재료] 해쉬브라운(냉동감자) 4장| 올리브유 적당량| 토마토소스 2/3컵| 슈...      2인분         초급
# 11  [필수재료] 해쉬브라운(냉동감자) 4장| 올리브유 적당량| 토마토소스 2/3컵| 슈...      2인분         초급
# 12  [필수재료] 식빵 3장| 소시지 3개| 슬라이스치즈 3장| 달걀 2개| 빵가루 1컵...      1인분         초급
# 13  [필수재료] 식빵 3장| 소시지 3개| 슬라이스치즈 3장| 달걀 2개| 빵가루 1컵...      1인분         초급
# 14  [필수재료] 식빵 3장| 소시지 3개| 슬라이스치즈 3장| 달걀 2개| 빵가루 1컵...      1인분         초급
# 15  [필수재료] 식빵 3장| 소시지 3개| 슬라이스치즈 3장| 달걀 2개| 빵가루 1컵...      1인분         초급
# 16  [필수재료] 머핀 2개| 딸기 8개| 플레인요구르트 1컵 [선택재료] 판 초콜릿 적...      2인분        아무나
# 17  [필수재료] 머핀 2개| 딸기 8개| 플레인요구르트 1컵 [선택재료] 판 초콜릿 적...      2인분        아무나
# 18  [필수재료] 머핀 2개| 딸기 8개| 플레인요구르트 1컵 [선택재료] 판 초콜릿 적...      2인분        아무나
# 19  [필수재료] 머핀 2개| 딸기 8개| 플레인요구르트 1컵 [선택재료] 판 초콜릿 적...      2인분        아무나
#
#                                             thumbnail    time  \
# 0   https://recipe1.ezmember.co.kr/cache/recipe/20...  60분 이내
# 1   https://recipe1.ezmember.co.kr/cache/recipe/20...  60분 이내
# 2   https://recipe1.ezmember.co.kr/cache/recipe/20...  60분 이내
# 3   https://recipe1.ezmember.co.kr/cache/recipe/20...  60분 이내
# 4   https://recipe1.ezmember.co.kr/cache/recipe/20...  10분 이내
# 5   https://recipe1.ezmember.co.kr/cache/recipe/20...  10분 이내
# 6   https://recipe1.ezmember.co.kr/cache/recipe/20...  10분 이내
# 7   https://recipe1.ezmember.co.kr/cache/recipe/20...  10분 이내
# 8   https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
# 9   https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
# 10  https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
# 11  https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
# 12  https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
# 13  https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
# 14  https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
# 15  https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
# 16  https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
# 17  https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
# 18  https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
# 19  https://recipe1.ezmember.co.kr/cache/recipe/20...  30분 이내
#
#                                                orders  \
# 0        |1. 바삭하게 튀기는 꿀팁|2. 달콤한 소스 꿀팁|3. 더 건강하게 먹는 꿀팁
# 1        |1. 바삭하게 튀기는 꿀팁|2. 달콤한 소스 꿀팁|3. 더 건강하게 먹는 꿀팁
# 2        |1. 바삭하게 튀기는 꿀팁|2. 달콤한 소스 꿀팁|3. 더 건강하게 먹는 꿀팁
# 3        |1. 바삭하게 튀기는 꿀팁|2. 달콤한 소스 꿀팁|3. 더 건강하게 먹는 꿀팁
# 4   |1. 참치는 캔 뚜껑을 따서 기름기를 따라낸다.|2. 볼에 참치를 넣고 다진 양파...
# 5   |1. 참치는 캔 뚜껑을 따서 기름기를 따라낸다.|2. 볼에 참치를 넣고 다진 양파...
# 6   |1. 참치는 캔 뚜껑을 따서 기름기를 따라낸다.|2. 볼에 참치를 넣고 다진 양파...
# 7   |1. 참치는 캔 뚜껑을 따서 기름기를 따라낸다.|2. 볼에 참치를 넣고 다진 양파...
# 8   |1. 뜨겁게 달군 팬에 올리브유(2큰술)를 두르고 채 썬 양파와 다진 마늘(½큰술...
# 9   |1. 뜨겁게 달군 팬에 올리브유(2큰술)를 두르고 채 썬 양파와 다진 마늘(½큰술...
# 10  |1. 뜨겁게 달군 팬에 올리브유(2큰술)를 두르고 채 썬 양파와 다진 마늘(½큰술...
# 11  |1. 뜨겁게 달군 팬에 올리브유(2큰술)를 두르고 채 썬 양파와 다진 마늘(½큰술...
# 12  |1. 식빵은 밀대를 이용해 납작하게 민다.|2. 깻잎 ? 슬라이스치즈 - 소시지 ...
# 13  |1. 식빵은 밀대를 이용해 납작하게 민다.|2. 깻잎 ? 슬라이스치즈 - 소시지 ...
# 14  |1. 식빵은 밀대를 이용해 납작하게 민다.|2. 깻잎 ? 슬라이스치즈 - 소시지 ...
# 15  |1. 식빵은 밀대를 이용해 납작하게 민다.|2. 깻잎 ? 슬라이스치즈 - 소시지 ...
# 16  |1. 머핀은 사방 1.5cm 크기로 썰어요.|2. 판초콜릿은 칼로 잘게 부숴요.|...
# 17  |1. 머핀은 사방 1.5cm 크기로 썰어요.|2. 판초콜릿은 칼로 잘게 부숴요.|...
# 18  |1. 머핀은 사방 1.5cm 크기로 썰어요.|2. 판초콜릿은 칼로 잘게 부숴요.|...
# 19  |1. 머핀은 사방 1.5cm 크기로 썰어요.|2. 판초콜릿은 칼로 잘게 부숴요.|...
#
#                                                 photo  userId  rating
# 0   |https://recipe1.ezmember.co.kr/cache/recipe/2...       1       5
# 1   |https://recipe1.ezmember.co.kr/cache/recipe/2...       2       5
# 2   |https://recipe1.ezmember.co.kr/cache/recipe/2...       3       5
# 3   |https://recipe1.ezmember.co.kr/cache/recipe/2...       4       5
# 4   |https://recipe1.ezmember.co.kr/cache/recipe/2...       1       6
# 5   |https://recipe1.ezmember.co.kr/cache/recipe/2...       2       5
# 6   |https://recipe1.ezmember.co.kr/cache/recipe/2...       3       6
# 7   |https://recipe1.ezmember.co.kr/cache/recipe/2...       4       4
# 8   |https://recipe1.ezmember.co.kr/cache/recipe/2...       1       4
# 9   |https://recipe1.ezmember.co.kr/cache/recipe/2...       2       5
# 10  |https://recipe1.ezmember.co.kr/cache/recipe/2...       3       4
# 11  |https://recipe1.ezmember.co.kr/cache/recipe/2...       4       4
# 12  |https://recipe1.ezmember.co.kr/cache/recipe/2...       1       4
# 13  |https://recipe1.ezmember.co.kr/cache/recipe/2...       2       5
# 14  |https://recipe1.ezmember.co.kr/cache/recipe/2...       3       6
# 15  |https://recipe1.ezmember.co.kr/cache/recipe/2...       4       5
# 16  |https://recipe1.ezmember.co.kr/cache/recipe/2...       1       4
# 17  |https://recipe1.ezmember.co.kr/cache/recipe/2...       2       7
# 18  |https://recipe1.ezmember.co.kr/cache/recipe/2...       3       4
# 19  |https://recipe1.ezmember.co.kr/cache/recipe/2...       4       5
